# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes_dataset.csv')
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  727.000000                768.000000  768.000000  768.000000
# mean    32.445942                  0.471876   33.240885    0.348958
# std      6.932789                  0.331329   11.760232    0.476951
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Age'].mean()
# Out:
# 33.240885416666664

# %%
df['BloodPressure'].std()
# Out:
# 19.355807170644777

# %%
df.fillna(df.mean(), inplace=True)

# %%
positive = df['Outcome'].sum()
negetive = df.shape[0] - positive
print('positive = ' + str(positive))
print('negetive = ' + str(negetive))
# Out:
# positive = 268
# negetive = 500

# %%
df.sort_values(['Age'], inplace=True)

# %%
df[df['Age'] > 60]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 223            7      142             60             33      190  28.800000
# 115            4      146             92              0        0  31.200000
# 129            0      105             84              0        0  27.900000
# 456            1      135             54              0        0  26.700000
# 579            2      197             70             99        0  34.700000
# 582           12      121             78             17        0  26.500000
# 763           10      101             76             48      180  32.900000
# 263            3      142             80             15        0  32.400000
# 479            4      132             86             31        0  28.000000
# 361            5      158             70              0        0  29.800000
# 509            8      120             78              0        0  25.000000
# ...

# %%
dfGroupbyResult = df.groupby('Outcome')
dfPositive = dfGroupbyResult.get_group(1)
dfNegetive = dfGroupbyResult.get_group(0)

# %%
dfPositive.mean()
# Out:
# Pregnancies                   4.865672
# Glucose                     141.257463
# BloodPressure                70.824627
# SkinThickness                22.164179
# Insulin                     100.335821
# BMI                          35.286557
# DiabetesPedigreeFunction      0.550500
# Age                          37.067164
# Outcome                       1.000000
# dtype: float64

# %%
dfNegetive.mean()
# Out:
# Pregnancies                   3.298000
# Glucose                     109.980000
# BloodPressure                68.184000
# SkinThickness                19.664000
# Insulin                      68.792000
# BMI                          30.923373
# DiabetesPedigreeFunction      0.429734
# Age                          31.190000
# Outcome                       0.000000
# dtype: float64

# %%
df.hist(
    
)
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.matshow(df.corr())
plt.show()
