# %% [markdown]
# Q1 : Part 1

# %%
import pandas as pd 
df = pd.read_csv("AdmissionPredict.csv")

df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  378.000000   380.000000         400.000000  400.000000
# mean   200.500000  316.759259   107.386842           3.087500    3.400000
# std    115.614301   11.415599     6.048645           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.250000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  380.000000  400.000000       384.000000
# mean     3.452500    8.604737    0.547500         0.724375
# std      0.898478    0.599167    0.498362         0.142964
# min      1.000000    6.800000    0.000000         0.340000
# ...

# %%
df.dropna(subset=["Chance of Admit"], inplace=True)
df.fillna(df.mean(), inplace=True)
df.describe()

# df.fillna(df.mod())
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  384.000000  384.000000   384.000000         384.000000  384.000000
# mean   198.523438  316.821429   107.452055           3.093750    3.411458
# std    115.174017   11.093878     5.872983           1.141005    1.012313
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%     98.750000  309.000000   103.750000           2.000000    2.500000
# 50%    197.500000  316.821429   107.452055           3.000000    3.500000
# 75%    298.250000  325.000000   111.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  384.000000  384.000000  384.000000       384.000000
# mean     3.459635    8.606181    0.544271         0.724375
# std      0.899121    0.583467    0.498686         0.142964
# min      1.000000    6.800000    0.000000         0.340000
# ...

# %%
import matplotlib.pyplot as plt
plt.subplot(3,3,1)
plt.scatter(df['Serial No.'], df['Chance of Admit'])
plt.subplot(3,3,2)
plt.scatter(df['GRE Score'], df['Chance of Admit'])
plt.subplot(3,3,3)
plt.scatter(df['TOEFL Score'], df['Chance of Admit'])
plt.subplot(3,3,4)
plt.scatter(df['University Rating'], df['Chance of Admit'])
plt.subplot(3,3,5)
plt.scatter(df['SOP'], df['Chance of Admit'])
plt.subplot(3,3,6)
plt.scatter(df['LOR '], df['Chance of Admit'])
plt.subplot(3,3,7)
plt.scatter(df['CGPA'], df['Chance of Admit'])
plt.subplot(3,3,8)
plt.scatter(df['Research'], df['Chance of Admit'])

# %%
df.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.101952    -0.149625          -0.162320
# GRE Score           -0.101952   1.000000     0.806427           0.659134
# TOEFL Score         -0.149625   0.806427     1.000000           0.676183
# University Rating   -0.162320   0.659134     0.676183           1.000000
# SOP                 -0.150616   0.604647     0.631823           0.735077
# LOR                 -0.078713   0.540105     0.543789           0.652685
# CGPA                -0.057292   0.788656     0.800463           0.734636
# Research            -0.067161   0.573412     0.496998           0.437787
# Chance of Admit      0.047057   0.785190     0.758489           0.707191
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.150616 -0.078713 -0.057292 -0.067161         0.047057
# GRE Score          0.604647  0.540105  0.788656  0.573412         0.785190
# ...

# %%
from sklearn.model_selection import train_test_split
new_df = df[['CGPA', 'Chance of Admit']].copy()

x = df.iloc[:,0:7].values
y = df['Chance of Admit'].values

x_train, x_vaild, y_train, y_valid = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=123)

# %%
# Out:
# 77
